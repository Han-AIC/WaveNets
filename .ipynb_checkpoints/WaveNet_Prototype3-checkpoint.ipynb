# %%
import sys, os
from glob import glob
import re
import time
from datetime import datetime 
import pydot 
# import graphviz

from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model

import tensorflow as tf
import scipy.io as sio
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import seaborn as sb
import psutil

# Directly importing from tf.keras for convenience
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, Dense, Flatten, Dropout, MaxPool1D, AveragePooling1D, MaxPool2D,GlobalMaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling2D, concatenate, Activation, Dropout, Lambda, Multiply, Add

from scipy.special import softmax
from sklearn.model_selection import train_test_split

print("--------- Sys Info ---------")
print(sys.version)
print(" ")
print("--------- Utility Info ---------")
print("Cpu Usage: " + str(psutil.cpu_percent()) + "%")
print("Memory Usage:")
print(psutil.virtual_memory())
print(" ")
print("--------- Package Versions ---------")
print("Tensorflow Version: " + tf.__version__)
print("Numpy Version: " + np.__version__)
print("Pandas Version: " + pd.__version__)
print("Matplotlib Version: " + mpl.__version__)
print(" ")
print("--------- Local Hardware ---------")
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# --------- Sys Info ---------
# 3.7.5 (default, Oct 31 2019, 15:18:51) [MSC v.1916 64 bit (AMD64)]
#
# --------- Utility Info ---------
# Cpu Usage: 1.1%
# Memory Usage:
# svmem(total=137302384640, available=126495698944, percent=7.9, used=10806685696, free=126495698944)
#
# --------- Package Versions ---------
# Tensorflow Version: 2.0.0
# Numpy Version: 1.17.4
# Pandas Version: 0.25.3
# Matplotlib Version: 3.1.3
#
# --------- Local Hardware ---------
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 11222690414906935841, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 9027596452
#  locality {
#    bus_id: 1
#    links {
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 7576531544982495068
#  physical_device_desc: "device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:0a:00.0, compute capability: 7.5", name: "/device:GPU:1"
#  device_type: "GPU"
#  memory_limit: 9027596452
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 9407791071378510838
#  physical_device_desc: "device: 1, name: GeForce RTX 2080 Ti, pci bus id: 0000:41:00.0, compute capability: 7.5"]

# %% [markdown]
# # WaveNet
#
# The goal here is to produce a generative model which can be used for prediction of time series data. The model below represents an implementation of a Convolutional WaveNetwork by Van den Oord et al. This current model is a testing/developmental prototype, and requires a 1-d input array of scalar values. Hence, it is set up only for single dimensional time-series data. With a small amount of work, it can be made ready for an input array of high dimensional vectors, such as words or audio waveforms.

# %% [markdown]
# ![](./diagrams/Architecture.jpg)

# %% [markdown]
# ![](./diagrams/residual_block.png)

# %%
'''
Convolutional Wavenet Model

'''

class WaveNet:
    def __init__(self, 
                input_dim,
                num_hidden_kernels,
                hidden_kernel_size,
                num_output_kernels,
                output_kernel_size,
                output_dim,
                activation_function,
                output_activation,
                lookback_length, 
                callbacks, 
                learning_rate, 
                momentum, 
                cost_function, 
                metrics, 
                optim):
        
        self.input_dim = input_dim 
        self.num_hidden_kernels = num_hidden_kernels
        self.hidden_kernel_size = hidden_kernel_size
        self.num_output_kernels = num_output_kernels
        self.output_kernel_size = output_kernel_size
        self.output_dim = output_dim
        
        self.activation_function = activation_function
        self.output_activation = output_activation
        self.lookback_length = lookback_length
        self.callbacks = callbacks 
        self.learning_rate = learning_rate 
        self.momentum = momentum 
        self.cost_function = cost_function
        self.metrics = metrics
        self.optim = optim
        
        self.model = None
        self.model_history = None
            
    def __prepare_input_layers(self):
      output = []
      for i in range(int(self.lookback_length)):
        output.append(Input(shape=(None, self.input_dim)))
      return output

    def __define_model(self):

        layers = [self.__prepare_input_layers()]
        skip_connections = []

        for i in range(np.log2(self.lookback_length).astype('int64')):
          layer_arr = []
          for j in range(int(self.lookback_length / 2**(i+1))):          
            if (i >= 0) and (i < (np.log2(lookback_length).astype('int64') - 1)):
              x = concatenate([layers[i][j*2], layers[i][j*2+1]])
              x = Conv1D(self.num_hidden_kernels, self.hidden_kernel_size, padding='same', activation=self.activation_function)(x) 
              x_filter = Conv1D(self.num_hidden_kernels, self.hidden_kernel_size, padding='same')(x) 
              x_gate = Conv1D(self.num_hidden_kernels, self.hidden_kernel_size, padding='same')(x)
              z = Multiply()([Activation('tanh')(x_filter), Activation('sigmoid')(x_gate)])
              z = Conv1D(self.num_hidden_kernels, self.hidden_kernel_size, padding='same', activation=self.activation_function)(z) 
              skip_connections.append(z)   
              x = Add()([x, z])
              layer_arr.append(x)
            
            else:
              output = Add()(skip_connections)
              output = Activation(self.activation_function)(output)
              output = Conv1D(self.num_output_kernels, self.output_kernel_size, padding='same', activation=self.activation_function)(output) 
              output = Dense(self.output_dim, activation=output_activation)(output)
              layer_arr.append(output)
            
          layers.append(layer_arr)

        self.model = Model(layers[0], 
                           layers[-1])
    
    def __compile_model(self, nesterov=True):

        self.model.compile(optimizer=optim(learning_rate=self.learning_rate, 
                                      momentum=self.momentum, 
                                      nesterov=nesterov), 
                      loss=self.cost_function, 
                      metrics=self.metrics)

    
    def build_model(self):
        self.__define_model()
        self.__compile_model()
        
    def return_model(self):
        return self.model
    
    def __sequence_data_window(self, arr, start):
        end = start + self.lookback_length

        if ((end - start) % 2 != 0 or (end - start) < 0):
            raise Exception('Need evenly sized window')

        output = [np.array([arr[i]]).reshape(1, 1,-1) for i in range(start, end)]
        return output


    def train_model(self, data):
      model_History = None
      for epoch in range(1):
        for i in range(0, len(data)-(self.lookback_length)):
            
          if(len(data)<self.lookback_length):
            raise Exception('Window Size must be lower than sequence length.')

          print(i)
          print(i+self.lookback_length)
            
          test_sequence = self.__sequence_data_window(data, i)
        
          print('-----------------------------')
          print(test_sequence)
          print(np.array([data[i+lookback_length]]))
            
          self.model_history = self.model.fit(test_sequence, np.array([data[i+self.lookback_length]]), epochs=1, batch_size = 1, callbacks=self.callbacks, verbose=True)
        
          print(self.model.predict(test_sequence)[0])
            
    def predict(self, data, time_steps):
        
        pred_data = data 
        while len(pred_data) < self.lookback_length:
            new_arr = [data[0]]
            new_arr += pred_data
            pred_data = new_arr
            

        for i in range(time_steps):
            current_pred_data = self.__sequence_data_window(pred_data, i)
            print(current_pred_data)
            prediction = self.model.predict(current_pred_data)
            pred_data.append(prediction)
            
            print(prediction)
            print(type(prediction))
            
def create_training_sequence(n, d):
    scaler = StandardScaler()

    sample = []

    power = np.random.normal(1, 1, 1)[0]
    base1 = np.random.normal(1, 0.5, 1)[0]
    base2 = 0
    for j in range(1, d):
      base1 += (j*2)
      base2 += base1**(power**2)
      sample.append(base1 + base2)

    sample = np.array(sample)
    sample -= np.mean(sample)
    sample /= np.std(sample)
    return np.array(sample)

input_dim = 1
num_hidden_kernels = 16
hidden_kernel_size = 1
num_output_kernels = 32
output_kernel_size = 1
output_dim = 1
activation_function = 'relu'
output_activation = 'linear'
lookback_length = 16

earlyStoppingCallback = EarlyStopping(monitor='loss', patience=3)
callbacks = [earlyStoppingCallback]

learning_rate = 0.05
momentum = 0.6 

cost_function = 'MSE'
metrics = ['mse']
optim = SGD

wavenet = WaveNet(input_dim,
                num_hidden_kernels,
                hidden_kernel_size,
                num_output_kernels,
                output_kernel_size,
                output_dim,
                activation_function,
                output_activation,
                lookback_length, 
                callbacks, 
                learning_rate, 
                momentum, 
                cost_function, 
                metrics, 
                optim)

wavenet.build_model()

plot_model(wavenet.return_model())

# %%
wavenet.return_model().summary()
# Out:
# Model: "model_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_297 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_298 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_299 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_300 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_301 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_302 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_303 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_304 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_305 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_306 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_307 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_308 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_309 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_310 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_311 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_312 (InputLayer)          [(None, None, 1)]    0
# __________________________________________________________________________________________________
# concatenate_115 (Concatenate)   (None, None, 2)      0           input_297[0][0]
#                                                                  input_298[0][0]
# __________________________________________________________________________________________________
# concatenate_116 (Concatenate)   (None, None, 2)      0           input_299[0][0]
#                                                                  input_300[0][0]
# __________________________________________________________________________________________________
# concatenate_117 (Concatenate)   (None, None, 2)      0           input_301[0][0]
#                                                                  input_302[0][0]
# __________________________________________________________________________________________________
# concatenate_118 (Concatenate)   (None, None, 2)      0           input_303[0][0]
#                                                                  input_304[0][0]
# __________________________________________________________________________________________________
# concatenate_119 (Concatenate)   (None, None, 2)      0           input_305[0][0]
#                                                                  input_306[0][0]
# __________________________________________________________________________________________________
# concatenate_120 (Concatenate)   (None, None, 2)      0           input_307[0][0]
#                                                                  input_308[0][0]
# __________________________________________________________________________________________________
# concatenate_121 (Concatenate)   (None, None, 2)      0           input_309[0][0]
#                                                                  input_310[0][0]
# __________________________________________________________________________________________________
# concatenate_122 (Concatenate)   (None, None, 2)      0           input_311[0][0]
#                                                                  input_312[0][0]
# __________________________________________________________________________________________________
# conv1d_385 (Conv1D)             (None, None, 16)     48          concatenate_115[0][0]
# __________________________________________________________________________________________________
# conv1d_389 (Conv1D)             (None, None, 16)     48          concatenate_116[0][0]
# __________________________________________________________________________________________________
# conv1d_393 (Conv1D)             (None, None, 16)     48          concatenate_117[0][0]
# __________________________________________________________________________________________________
# conv1d_397 (Conv1D)             (None, None, 16)     48          concatenate_118[0][0]
# __________________________________________________________________________________________________
# conv1d_401 (Conv1D)             (None, None, 16)     48          concatenate_119[0][0]
# __________________________________________________________________________________________________
# conv1d_405 (Conv1D)             (None, None, 16)     48          concatenate_120[0][0]
# __________________________________________________________________________________________________
# conv1d_409 (Conv1D)             (None, None, 16)     48          concatenate_121[0][0]
# __________________________________________________________________________________________________
# conv1d_413 (Conv1D)             (None, None, 16)     48          concatenate_122[0][0]
# __________________________________________________________________________________________________
# conv1d_386 (Conv1D)             (None, None, 16)     272         conv1d_385[0][0]
# __________________________________________________________________________________________________
# conv1d_387 (Conv1D)             (None, None, 16)     272         conv1d_385[0][0]
# __________________________________________________________________________________________________
# conv1d_390 (Conv1D)             (None, None, 16)     272         conv1d_389[0][0]
# __________________________________________________________________________________________________
# conv1d_391 (Conv1D)             (None, None, 16)     272         conv1d_389[0][0]
# __________________________________________________________________________________________________
# conv1d_394 (Conv1D)             (None, None, 16)     272         conv1d_393[0][0]
# __________________________________________________________________________________________________
# conv1d_395 (Conv1D)             (None, None, 16)     272         conv1d_393[0][0]
# __________________________________________________________________________________________________
# conv1d_398 (Conv1D)             (None, None, 16)     272         conv1d_397[0][0]
# __________________________________________________________________________________________________
# conv1d_399 (Conv1D)             (None, None, 16)     272         conv1d_397[0][0]
# __________________________________________________________________________________________________
# conv1d_402 (Conv1D)             (None, None, 16)     272         conv1d_401[0][0]
# __________________________________________________________________________________________________
# conv1d_403 (Conv1D)             (None, None, 16)     272         conv1d_401[0][0]
# __________________________________________________________________________________________________
# conv1d_406 (Conv1D)             (None, None, 16)     272         conv1d_405[0][0]
# __________________________________________________________________________________________________
# conv1d_407 (Conv1D)             (None, None, 16)     272         conv1d_405[0][0]
# __________________________________________________________________________________________________
# conv1d_410 (Conv1D)             (None, None, 16)     272         conv1d_409[0][0]
# __________________________________________________________________________________________________
# conv1d_411 (Conv1D)             (None, None, 16)     272         conv1d_409[0][0]
# __________________________________________________________________________________________________
# conv1d_414 (Conv1D)             (None, None, 16)     272         conv1d_413[0][0]
# __________________________________________________________________________________________________
# conv1d_415 (Conv1D)             (None, None, 16)     272         conv1d_413[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, None, 16)     0           conv1d_386[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, None, 16)     0           conv1d_387[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, None, 16)     0           conv1d_390[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, None, 16)     0           conv1d_391[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, None, 16)     0           conv1d_394[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, None, 16)     0           conv1d_395[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, None, 16)     0           conv1d_398[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, None, 16)     0           conv1d_399[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, None, 16)     0           conv1d_402[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, None, 16)     0           conv1d_403[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, None, 16)     0           conv1d_406[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, None, 16)     0           conv1d_407[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, None, 16)     0           conv1d_410[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, None, 16)     0           conv1d_411[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, None, 16)     0           conv1d_414[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, None, 16)     0           conv1d_415[0][0]
# __________________________________________________________________________________________________
# multiply_90 (Multiply)          (None, None, 16)     0           activation_186[0][0]
#                                                                  activation_187[0][0]
# __________________________________________________________________________________________________
# multiply_91 (Multiply)          (None, None, 16)     0           activation_188[0][0]
#                                                                  activation_189[0][0]
# __________________________________________________________________________________________________
# multiply_92 (Multiply)          (None, None, 16)     0           activation_190[0][0]
#                                                                  activation_191[0][0]
# __________________________________________________________________________________________________
# multiply_93 (Multiply)          (None, None, 16)     0           activation_192[0][0]
#                                                                  activation_193[0][0]
# __________________________________________________________________________________________________
# multiply_94 (Multiply)          (None, None, 16)     0           activation_194[0][0]
#                                                                  activation_195[0][0]
# __________________________________________________________________________________________________
# multiply_95 (Multiply)          (None, None, 16)     0           activation_196[0][0]
#                                                                  activation_197[0][0]
# __________________________________________________________________________________________________
# multiply_96 (Multiply)          (None, None, 16)     0           activation_198[0][0]
#                                                                  activation_199[0][0]
# __________________________________________________________________________________________________
# multiply_97 (Multiply)          (None, None, 16)     0           activation_200[0][0]
#                                                                  activation_201[0][0]
# __________________________________________________________________________________________________
# conv1d_388 (Conv1D)             (None, None, 16)     272         multiply_90[0][0]
# __________________________________________________________________________________________________
# conv1d_392 (Conv1D)             (None, None, 16)     272         multiply_91[0][0]
# __________________________________________________________________________________________________
# conv1d_396 (Conv1D)             (None, None, 16)     272         multiply_92[0][0]
# __________________________________________________________________________________________________
# conv1d_400 (Conv1D)             (None, None, 16)     272         multiply_93[0][0]
# __________________________________________________________________________________________________
# conv1d_404 (Conv1D)             (None, None, 16)     272         multiply_94[0][0]
# __________________________________________________________________________________________________
# conv1d_408 (Conv1D)             (None, None, 16)     272         multiply_95[0][0]
# __________________________________________________________________________________________________
# conv1d_412 (Conv1D)             (None, None, 16)     272         multiply_96[0][0]
# __________________________________________________________________________________________________
# conv1d_416 (Conv1D)             (None, None, 16)     272         multiply_97[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, None, 16)     0           conv1d_385[0][0]
#                                                                  conv1d_388[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, None, 16)     0           conv1d_389[0][0]
#                                                                  conv1d_392[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, None, 16)     0           conv1d_393[0][0]
#                                                                  conv1d_396[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, None, 16)     0           conv1d_397[0][0]
#                                                                  conv1d_400[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, None, 16)     0           conv1d_401[0][0]
#                                                                  conv1d_404[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, None, 16)     0           conv1d_405[0][0]
#                                                                  conv1d_408[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, None, 16)     0           conv1d_409[0][0]
#                                                                  conv1d_412[0][0]
# __________________________________________________________________________________________________
# add_66 (Add)                    (None, None, 16)     0           conv1d_413[0][0]
#                                                                  conv1d_416[0][0]
# __________________________________________________________________________________________________
# concatenate_123 (Concatenate)   (None, None, 32)     0           add_59[0][0]
#                                                                  add_60[0][0]
# __________________________________________________________________________________________________
# concatenate_124 (Concatenate)   (None, None, 32)     0           add_61[0][0]
#                                                                  add_62[0][0]
# __________________________________________________________________________________________________
# concatenate_125 (Concatenate)   (None, None, 32)     0           add_63[0][0]
#                                                                  add_64[0][0]
# __________________________________________________________________________________________________
# concatenate_126 (Concatenate)   (None, None, 32)     0           add_65[0][0]
#                                                                  add_66[0][0]
# __________________________________________________________________________________________________
# conv1d_417 (Conv1D)             (None, None, 16)     528         concatenate_123[0][0]
# __________________________________________________________________________________________________
# conv1d_421 (Conv1D)             (None, None, 16)     528         concatenate_124[0][0]
# __________________________________________________________________________________________________
# conv1d_425 (Conv1D)             (None, None, 16)     528         concatenate_125[0][0]
# __________________________________________________________________________________________________
# conv1d_429 (Conv1D)             (None, None, 16)     528         concatenate_126[0][0]
# __________________________________________________________________________________________________
# conv1d_418 (Conv1D)             (None, None, 16)     272         conv1d_417[0][0]
# __________________________________________________________________________________________________
# conv1d_419 (Conv1D)             (None, None, 16)     272         conv1d_417[0][0]
# __________________________________________________________________________________________________
# conv1d_422 (Conv1D)             (None, None, 16)     272         conv1d_421[0][0]
# __________________________________________________________________________________________________
# conv1d_423 (Conv1D)             (None, None, 16)     272         conv1d_421[0][0]
# __________________________________________________________________________________________________
# conv1d_426 (Conv1D)             (None, None, 16)     272         conv1d_425[0][0]
# __________________________________________________________________________________________________
# conv1d_427 (Conv1D)             (None, None, 16)     272         conv1d_425[0][0]
# __________________________________________________________________________________________________
# conv1d_430 (Conv1D)             (None, None, 16)     272         conv1d_429[0][0]
# __________________________________________________________________________________________________
# conv1d_431 (Conv1D)             (None, None, 16)     272         conv1d_429[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, None, 16)     0           conv1d_418[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, None, 16)     0           conv1d_419[0][0]
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, None, 16)     0           conv1d_422[0][0]
# __________________________________________________________________________________________________
# activation_205 (Activation)     (None, None, 16)     0           conv1d_423[0][0]
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, None, 16)     0           conv1d_426[0][0]
# __________________________________________________________________________________________________
# activation_207 (Activation)     (None, None, 16)     0           conv1d_427[0][0]
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, None, 16)     0           conv1d_430[0][0]
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, None, 16)     0           conv1d_431[0][0]
# __________________________________________________________________________________________________
# multiply_98 (Multiply)          (None, None, 16)     0           activation_202[0][0]
#                                                                  activation_203[0][0]
# __________________________________________________________________________________________________
# multiply_99 (Multiply)          (None, None, 16)     0           activation_204[0][0]
#                                                                  activation_205[0][0]
# __________________________________________________________________________________________________
# multiply_100 (Multiply)         (None, None, 16)     0           activation_206[0][0]
#                                                                  activation_207[0][0]
# __________________________________________________________________________________________________
# multiply_101 (Multiply)         (None, None, 16)     0           activation_208[0][0]
#                                                                  activation_209[0][0]
# __________________________________________________________________________________________________
# conv1d_420 (Conv1D)             (None, None, 16)     272         multiply_98[0][0]
# __________________________________________________________________________________________________
# conv1d_424 (Conv1D)             (None, None, 16)     272         multiply_99[0][0]
# __________________________________________________________________________________________________
# conv1d_428 (Conv1D)             (None, None, 16)     272         multiply_100[0][0]
# __________________________________________________________________________________________________
# conv1d_432 (Conv1D)             (None, None, 16)     272         multiply_101[0][0]
# __________________________________________________________________________________________________
# add_67 (Add)                    (None, None, 16)     0           conv1d_417[0][0]
#                                                                  conv1d_420[0][0]
# __________________________________________________________________________________________________
# add_68 (Add)                    (None, None, 16)     0           conv1d_421[0][0]
#                                                                  conv1d_424[0][0]
# __________________________________________________________________________________________________
# add_69 (Add)                    (None, None, 16)     0           conv1d_425[0][0]
#                                                                  conv1d_428[0][0]
# __________________________________________________________________________________________________
# add_70 (Add)                    (None, None, 16)     0           conv1d_429[0][0]
#                                                                  conv1d_432[0][0]
# __________________________________________________________________________________________________
# concatenate_127 (Concatenate)   (None, None, 32)     0           add_67[0][0]
#                                                                  add_68[0][0]
# __________________________________________________________________________________________________
# concatenate_128 (Concatenate)   (None, None, 32)     0           add_69[0][0]
#                                                                  add_70[0][0]
# __________________________________________________________________________________________________
# conv1d_433 (Conv1D)             (None, None, 16)     528         concatenate_127[0][0]
# __________________________________________________________________________________________________
# conv1d_437 (Conv1D)             (None, None, 16)     528         concatenate_128[0][0]
# __________________________________________________________________________________________________
# conv1d_434 (Conv1D)             (None, None, 16)     272         conv1d_433[0][0]
# __________________________________________________________________________________________________
# conv1d_435 (Conv1D)             (None, None, 16)     272         conv1d_433[0][0]
# __________________________________________________________________________________________________
# conv1d_438 (Conv1D)             (None, None, 16)     272         conv1d_437[0][0]
# __________________________________________________________________________________________________
# conv1d_439 (Conv1D)             (None, None, 16)     272         conv1d_437[0][0]
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, None, 16)     0           conv1d_434[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, None, 16)     0           conv1d_435[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, None, 16)     0           conv1d_438[0][0]
# __________________________________________________________________________________________________
# activation_213 (Activation)     (None, None, 16)     0           conv1d_439[0][0]
# __________________________________________________________________________________________________
# multiply_102 (Multiply)         (None, None, 16)     0           activation_210[0][0]
#                                                                  activation_211[0][0]
# __________________________________________________________________________________________________
# multiply_103 (Multiply)         (None, None, 16)     0           activation_212[0][0]
#                                                                  activation_213[0][0]
# __________________________________________________________________________________________________
# conv1d_436 (Conv1D)             (None, None, 16)     272         multiply_102[0][0]
# __________________________________________________________________________________________________
# conv1d_440 (Conv1D)             (None, None, 16)     272         multiply_103[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, None, 16)     0           conv1d_388[0][0]
#                                                                  conv1d_392[0][0]
#                                                                  conv1d_396[0][0]
#                                                                  conv1d_400[0][0]
#                                                                  conv1d_404[0][0]
#                                                                  conv1d_408[0][0]
#                                                                  conv1d_412[0][0]
#                                                                  conv1d_416[0][0]
#                                                                  conv1d_420[0][0]
#                                                                  conv1d_424[0][0]
#                                                                  conv1d_428[0][0]
#                                                                  conv1d_432[0][0]
#                                                                  conv1d_436[0][0]
#                                                                  conv1d_440[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, None, 16)     0           add_73[0][0]
# __________________________________________________________________________________________________
# conv1d_441 (Conv1D)             (None, None, 32)     544         activation_214[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, None, 1)      33          conv1d_441[0][0]
# ==================================================================================================
# Total params: 15,553
# Trainable params: 15,553
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
np.array([12]).reshape(1, 1,-1)[0][0][0]
# Out:
# 12

# %%
create_training_sequence(1, 64)
# Out:
# array([-1.12002584, -1.11694538, -1.11239299, -1.10634068, -1.09876719,
#        -1.08965517, -1.07898986, -1.06675835, -1.05294914, -1.03755182,
#        -1.02055691, -1.00195563, -0.98173984, -0.95990196, -0.93643483,
#        -0.91133173, -0.88458628, -0.85619244, -0.82614442, -0.79443673,
#        -0.76106409, -0.72602143, -0.6893039 , -0.65090681, -0.61082565,
#        -0.56905604, -0.52559377, -0.48043476, -0.43357503, -0.38501074,
#        -0.33473815, -0.28275364, -0.22905365, -0.17363476, -0.11649358,
#        -0.05762686,  0.00296861,  0.06529597,  0.12935825,  0.19515846,
#         0.26269951,  0.33198428,  0.40301557,  0.47579612,  0.55032864,
#         0.62661577,  0.70466011,  0.78446421,  0.86603056,  0.94936164,
#         1.03445986,  1.12132759,  1.20996718,  1.30038093,  1.3925711 ,
#         1.48653991,  1.58228958,  1.67982225,  1.77914005,  1.8802451 ,
#         1.98313945,  2.08782515,  2.19430421])

# %%
test_data = create_training_sequence(1, 128)
model_History = wavenet.train_model(test_data)
# Out:
# 0
# 16
# -----------------------------
# [array([[[-0.63406603]]]), array([[[-0.63406603]]]), array([[[-0.63406601]]]), array([[[-0.63406596]]]), array([[[-0.63406584]]]), array([[[-0.63406558]]]), array([[[-0.6340651]]]), array([[[-0.63406426]]]), array([[[-0.63406287]]]), array([[[-0.6340607]]]), array([[[-0.63405744]]]), array([[[-0.63405269]]]), array([[[-0.63404597]]]), array([[[-0.6340367]]]), array([[[-0.63402418]]]), array([[[-0.6340076]]])]
# [-0.63398597]
# Train on 1 samples
# 1/1 [==============================] - 5s 5s/sample - loss: 0.6662 - mse: 0.6662

# Train on 1 samples
# 1/1 [==============================] - 0s 33ms/sample - loss: 2.4839 - mse: 2.4839
# [[1.8955619]]
# 108
# 124
# -----------------------------
# [array([[[1.09840054]]]), array([[[1.1870881]]]), array([[[1.27945879]]]), array([[[1.37563062]]]), array([[[1.47572428]]]), array([[[1.57986318]]]), array([[[1.6881735]]]), array([[[1.80078419]]]), array([[[1.91782705]]]), array([[[2.03943673]]]), array([[[2.16575078]]]), array([[[2.29690971]]]), array([[[2.43305699]]]), array([[[2.57433911]]]), array([[[2.72090561]]]), array([[[2.87290913]]])]
# [3.03050544]
# Train on 1 samples
# 1/1 [==============================] - 0s 32ms/sample - loss: 1.2507 - mse: 1.2507
# [[2.8742592]]
# 109
# 125
# -----------------------------
# [array([[[1.1870881]]]), array([[[1.27945879]]]), array([[[1.37563062]]]), array([[[1.47572428]]]), array([[[1.57986318]]]), array([[[1.6881735]]]), array([[[1.80078419]]]), array([[[1.91782705]]]), array([[[2.03943673]]]), array([[[2.16575078]]]), array([[[2.29690971]]]), array([[[2.43305699]]]), array([[[2.57433911]]]), array([[[2.72090561]]]), array([[[2.87290913]]]), array([[[3.03050544]]])]
# [3.19385346]
# Train on 1 samples
# 1/1 [==============================] - 0s 33ms/sample - loss: 0.0795 - mse: 0.0795
# [[3.755122]]
# 110
# 126
# -----------------------------
# [array([[[1.27945879]]]), array([[[1.37563062]]]), array([[[1.47572428]]]), array([[[1.57986318]]]), array([[[1.6881735]]]), array([[[1.80078419]]]), array([[[1.91782705]]]), array([[[2.03943673]]]), array([[[2.16575078]]]), array([[[2.29690971]]]), array([[[2.43305699]]]), array([[[2.57433911]]]), array([[[2.72090561]]]), array([[[2.87290913]]]), array([[[3.03050544]]]), array([[[3.19385346]]])]
# [3.36311534]
# Train on 1 samples
# 1/1 [==============================] - 0s 30ms/sample - loss: 0.2026 - mse: 0.2026
# [[2.9947386]]

# %%
test = [2.87290913, 3.03050544]

wavenet.predict(test, 2)
# Out:
# [array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[3.03050544]]])]
# [[[3.0910652]]]
# <class 'numpy.ndarray'>
# [array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[2.87290913]]]), array([[[3.03050544]]]), array([[[3.0910652]]], dtype=float32)]
# [[[3.096723]]]
# <class 'numpy.ndarray'>

# %%
plot_model(wavenet.return_model())

# %%
# Out:
# [-0.38218366 -0.38218366 -0.38218366 -0.38218366 -0.38218366 -0.38218365
#  -0.38218353 -0.3821828  -0.38217916 -0.38216348 -0.38210427 -0.38190359
#  -0.38128342 -0.37951309 -0.37479657 -0.36296895 -0.33485486 -0.27113883
#  -0.13277479  0.15634762  0.73979275  1.88041454  4.04659437]
# <class 'numpy.ndarray'>
# (23,)

# %%
# Out:
# [array([[-0.38218366]]), array([[-0.38218365]]), array([[-0.38218353]]), array([[-0.3821828]]), array([[-0.38217916]]), array([[-0.38216348]]), array([[-0.38210427]]), array([[-0.38190359]])]
# <class 'list'>
# <class 'numpy.ndarray'>
# (1, 1)
